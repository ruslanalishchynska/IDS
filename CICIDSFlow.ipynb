# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_csv('drive/My Drive/datasets/CICIDS_2017/MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')
df2 = pd.read_csv('drive/My Drive/datasets/CICIDS_2017/MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')
df3 = pd.read_csv('drive/My Drive/datasets/CICIDS_2017/MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv')
df4 = pd.read_csv('drive/My Drive/datasets/CICIDS_2017/MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv')
df5 = pd.read_csv('drive/My Drive/datasets/CICIDS_2017/MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv')
df6 = pd.read_csv('drive/My Drive/datasets/CICIDS_2017/MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')
df7 = pd.read_csv('drive/My Drive/datasets/CICIDS_2017/MachineLearningCVE/Tuesday-WorkingHours.pcap_ISCX.csv')
df8 = pd.read_csv('drive/My Drive/datasets/CICIDS_2017/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv')

# %%
pcap = pd.read_csv('drive/My Drive/datasets/2020-06-11_Flow.csv')

# %%
pcap.head()
# Out:
#                                    Flow ID  ...     Label
# 0  192.168.0.103-77.120.15.110-40352-443-6  ...  No Label
# 1  77.120.15.111-192.168.0.103-443-54080-6  ...  No Label
# 2  192.168.0.103-216.58.209.14-36310-443-6  ...  No Label
# 3  192.168.0.103-216.58.209.14-36310-443-6  ...  No Label
# 4  192.168.0.103-216.58.215.77-40244-443-6  ...  No Label
#
# [5 rows x 84 columns]

# %%
df1.head()
# Out:
#     Destination Port   Flow Duration  ...   Idle Min   Label
# 0              54865               3  ...          0  BENIGN
# 1              55054             109  ...          0  BENIGN
# 2              55055              52  ...          0  BENIGN
# 3              46236              34  ...          0  BENIGN
# 4              54863               3  ...          0  BENIGN
#
# [5 rows x 79 columns]

# %%
df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8])

# %%
del df1
del df2
del df3
del df4
del df5
del df6
del df7
del df8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2830743 entries, 0 to 692702
# Data columns (total 79 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0    Destination Port             int64
#  1    Flow Duration                int64
#  2    Total Fwd Packets            int64
#  3    Total Backward Packets       int64
#  4   Total Length of Fwd Packets   int64
#  5    Total Length of Bwd Packets  int64
#  6    Fwd Packet Length Max        int64
#  7    Fwd Packet Length Min        int64
#  8    Fwd Packet Length Mean       float64
#  9    Fwd Packet Length Std        float64
#  10  Bwd Packet Length Max         int64
#  11   Bwd Packet Length Min        int64
#  12   Bwd Packet Length Mean       float64
#  13   Bwd Packet Length Std        float64
#  14  Flow Bytes/s                  float64
#  15   Flow Packets/s               float64
#  16   Flow IAT Mean                float64
#  17   Flow IAT Std                 float64
# ...

# %%
pcap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278 entries, 0 to 1277
# Data columns (total 84 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Flow ID            1278 non-null   object
#  1   Src IP             1278 non-null   object
#  2   Src Port           1278 non-null   int64
#  3   Dst IP             1278 non-null   object
#  4   Dst Port           1278 non-null   int64
#  5   Protocol           1278 non-null   int64
#  6   Timestamp          1278 non-null   object
#  7   Flow Duration      1278 non-null   int64
#  8   Tot Fwd Pkts       1278 non-null   int64
#  9   Tot Bwd Pkts       1278 non-null   int64
#  10  TotLen Fwd Pkts    1278 non-null   float64
#  11  TotLen Bwd Pkts    1278 non-null   float64
#  12  Fwd Pkt Len Max    1278 non-null   float64
#  13  Fwd Pkt Len Min    1278 non-null   float64
#  14  Fwd Pkt Len Mean   1278 non-null   float64
#  15  Fwd Pkt Len Std    1278 non-null   float64
# ...

# %%
df.columns
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
# ...

# %%
pcap.columns
# Out:
# Index(['Flow ID', 'Src IP', 'Src Port', 'Dst IP', 'Dst Port', 'Protocol',
#        'Timestamp', 'Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts',
#        'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max',
#        'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std',
#        'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean',
#        'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean',
#        'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot',
#        'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min',
#        'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max',
#        'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags',
#        'Bwd URG Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s',
#        'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean',
#        'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt',
#        'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt',
# ...

# %%
pcap = pcap.drop(['Flow ID', 'Src IP', 'Src Port', 'Dst IP', 'Protocol', 'Timestamp'], axis=1)

# %%
pcap.head()
# Out:
#    Dst Port  Flow Duration  Tot Fwd Pkts  ...      Idle Max      Idle Min     Label
# 0       443          23164             1  ...  0.000000e+00  0.000000e+00  No Label
# 1     54080        7109135             1  ...  7.022435e+06  7.022435e+06  No Label
# 2       443       59745764             2  ...  1.591875e+15  1.591874e+15  No Label
# 3       443          14011             1  ...  0.000000e+00  0.000000e+00  No Label
# 4       443       58312187             2  ...  1.591875e+15  1.591874e+15  No Label
#
# [5 rows x 78 columns]

# %%
df = df.drop([' Fwd Header Length.1'], axis=1)

# %%
train_columns = df.columns

# %%
test_columns = pcap.columns

# %%
common_cols = train_columns.intersection(test_columns)

# %%
train_not_test = train_columns.difference(test_columns)

# %%
common_cols
# Out:
# Index(['Fwd PSH Flags', 'Active Mean', 'Idle Mean'], dtype='object')

# %%
train_not_test
# Out:
# Index([' ACK Flag Count', ' Active Max', ' Active Min', ' Active Std',
#        ' Average Packet Size', ' Avg Bwd Segment Size',
#        ' Avg Fwd Segment Size', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk',
#        ' Bwd Header Length', ' Bwd IAT Max', ' Bwd IAT Mean', ' Bwd IAT Min',
#        ' Bwd IAT Std', ' Bwd PSH Flags', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Std', ' Bwd Packets/s',
#        ' Bwd URG Flags', ' CWE Flag Count', ' Destination Port',
#        ' Down/Up Ratio', ' ECE Flag Count', ' Flow Duration', ' Flow IAT Max',
#        ' Flow IAT Mean', ' Flow IAT Min', ' Flow IAT Std', ' Flow Packets/s',
#        ' Fwd Avg Bulk Rate', ' Fwd Avg Packets/Bulk', ' Fwd Header Length',
#        ' Fwd IAT Max', ' Fwd IAT Mean', ' Fwd IAT Min', ' Fwd IAT Std',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Std', ' Fwd URG Flags',
# ...

# %%
test_columns.sort_values()
# Out:
# Index(['ACK Flag Cnt', 'Active Max', 'Active Mean', 'Active Min', 'Active Std',
#        'Bwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Header Len', 'Bwd IAT Max',
#        'Bwd IAT Mean', 'Bwd IAT Min', 'Bwd IAT Std', 'Bwd IAT Tot',
#        'Bwd PSH Flags', 'Bwd Pkt Len Max', 'Bwd Pkt Len Mean',
#        'Bwd Pkt Len Min', 'Bwd Pkt Len Std', 'Bwd Pkts/b Avg', 'Bwd Pkts/s',
#        'Bwd Seg Size Avg', 'Bwd URG Flags', 'CWE Flag Count', 'Down/Up Ratio',
#        'Dst Port', 'ECE Flag Cnt', 'FIN Flag Cnt', 'Flow Byts/s',
#        'Flow Duration', 'Flow IAT Max', 'Flow IAT Mean', 'Flow IAT Min',
#        'Flow IAT Std', 'Flow Pkts/s', 'Fwd Act Data Pkts', 'Fwd Blk Rate Avg',
#        'Fwd Byts/b Avg', 'Fwd Header Len', 'Fwd IAT Max', 'Fwd IAT Mean',
#        'Fwd IAT Min', 'Fwd IAT Std', 'Fwd IAT Tot', 'Fwd PSH Flags',
#        'Fwd Pkt Len Max', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Min',
#        'Fwd Pkt Len Std', 'Fwd Pkts/b Avg', 'Fwd Pkts/s', 'Fwd Seg Size Avg',
# ...

# %%
df[' Label'].unique()
# Out:
# array(['BENIGN', 'DDoS', 'PortScan', 'Bot', 'Infiltration',
#        'Web Attack � Brute Force', 'Web Attack � XSS',
#        'Web Attack � Sql Injection', 'FTP-Patator', 'SSH-Patator',
#        'DoS slowloris', 'DoS Slowhttptest', 'DoS Hulk', 'DoS GoldenEye',
#        'Heartbleed'], dtype=object)

# %%
df.columns.sort_values()
# Out:
# Index([' ACK Flag Count', ' Active Max', ' Active Min', ' Active Std',
#        ' Average Packet Size', ' Avg Bwd Segment Size',
#        ' Avg Fwd Segment Size', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk',
#        ' Bwd Header Length', ' Bwd IAT Max', ' Bwd IAT Mean', ' Bwd IAT Min',
#        ' Bwd IAT Std', ' Bwd PSH Flags', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Std', ' Bwd Packets/s',
#        ' Bwd URG Flags', ' CWE Flag Count', ' Destination Port',
#        ' Down/Up Ratio', ' ECE Flag Count', ' Flow Duration', ' Flow IAT Max',
#        ' Flow IAT Mean', ' Flow IAT Min', ' Flow IAT Std', ' Flow Packets/s',
#        ' Fwd Avg Bulk Rate', ' Fwd Avg Packets/Bulk', ' Fwd Header Length',
#        ' Fwd IAT Max', ' Fwd IAT Mean', ' Fwd IAT Min', ' Fwd IAT Std',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Std', ' Fwd URG Flags',
# ...

# %%
clear_df_data = df.rename(columns={' ACK Flag Count':'ack_flag_count', ' Active Max':'active_max', 
                                   ' Active Min':'active_min', ' Active Std':'active_std',
                                  ' Average Packet Size':'avg_packet_size', ' Avg Bwd Segment Size':'avg_bwd_segment_size',
                                  ' Avg Fwd Segment Size':'avg_fwd_segment_size', ' Bwd Avg Bytes/Bulk':'bwd_avg_bytes_bulk', 
                                  ' Bwd Avg Packets/Bulk':'bwd_avg_packets_bulk', ' Bwd Header Length':'bwd_header_length', 
                                  ' Bwd IAT Max':'bwd_iat_max', ' Bwd IAT Mean':'bwd_iat_mean',
                                  ' Bwd IAT Min':'bwd_iat_min', ' Bwd IAT Std':'bwd_iat_std', 
                                  ' Bwd PSH Flags':'bwd_psh_flags', ' Bwd Packet Length Mean':'bwd_packet_length_mean',
                                  ' Bwd Packet Length Min':'bwd_packet_length_min', ' Bwd Packet Length Std':'bwd_packet_length_std',
                                  ' Bwd Packets/s':'bwd_packets_s', ' Bwd URG Flags':'bwd_urg_flags', 
                                  ' CWE Flag Count':'cwe_flag_count', ' Destination Port':'destination_port',
                                  ' Down/Up Ratio':'down_up_ratio', ' ECE Flag Count':'ece_flag_count', 
                                  ' Flow Duration':'flow_duration', ' Flow IAT Max':'flow_iat_max',
                                  ' Flow IAT Mean':'flow_iat_mean', ' Flow IAT Min':'flow_iat_min', 
                                  ' Flow IAT Std':'flow_iat_std', ' Flow Packets/s':'flow_packets_s',
                                  ' Fwd Avg Bulk Rate':'fwd_avg_bulk_rate', ' Fwd Avg Packets/Bulk':'fwd_avg_packets_bulk', 
                                  ' Fwd Header Length':'fwd_header_length', ' Fwd IAT Max':'fwd_iat_max',
                                  ' Fwd IAT Mean':'fwd_iat_mean', ' Fwd IAT Min':'fwd_iat_min', 
                                  ' Fwd IAT Std':'fwd_iat_std', ' Fwd Packet Length Max':'fwd_packet_length_max', 
                                  ' Fwd Packet Length Mean':'fwd_packet_length_mean', ' Fwd Packet Length Min':'fwd_packet_length_min', 
                                  ' Fwd Packet Length Std':'fwd_packet_length_std', ' Fwd URG Flags':'fwd_urg_flags',
                                  ' Idle Max':'idle_max', ' Idle Min':'idle_min', ' Idle Std':'idle_std', 
                                  ' Init_Win_bytes_backward':'init_win_bytes_bwd', ' Label':'label', 
                                  ' Max Packet Length':'max_packet_length', ' Min Packet Length':'min_packet_length', 
                                  ' PSH Flag Count':'psh_flag_count', ' Packet Length Mean':'packet_length_mean', 
                                  ' Packet Length Std':'packet_length_std', ' Packet Length Variance':'packet_length_variance',
                                  ' RST Flag Count':'rst_flag_count', ' SYN Flag Count':'syn_flag_count', 
                                  ' Subflow Bwd Bytes':'subflow_bwd_bytes', ' Subflow Bwd Packets':'subflow_bwd_packets', 
                                  ' Subflow Fwd Bytes':'subflow_fwd_bytes', ' Total Backward Packets':'total_bwd_packets',
                                  ' Total Fwd Packets':'total_fwd_packets', ' Total Length of Bwd Packets':'total_length_of_bwd_packets', 
                                  ' URG Flag Count':'urg_flag_count', ' act_data_pkt_fwd':'act_data_pkt_fwd', 
                                  ' min_seg_size_forward':'min_seg_size_forward', 'Active Mean':'active_mean',
                                  'Bwd Avg Bulk Rate':'bwd_avg_bulk_rate', 'Bwd IAT Total':'bwd_iat_total', 
                                  'Bwd Packet Length Max':'bwd_packet_length_max', 'FIN Flag Count':'fin_flag_count', 
                                  'Flow Bytes/s':'flow_bytes_s', 'Fwd Avg Bytes/Bulk':'fwd_avg_bytes_bulk', 
                                  'Fwd IAT Total':'fwd_iat_total', 'Fwd PSH Flags':'fwd_psh_flags', 
                                  'Fwd Packets/s':'fwd_packets_s', 'Idle Mean':'idle_mean', 
                                  'Init_Win_bytes_forward':'init_win_bytes_fwd', 'Subflow Fwd Packets':'subflow_fwd_packets', 
                                  'Total Length of Fwd Packets':'total_length_of_fwd_packets'})

# %%
clear_df_data.head()
# Out:
#    destination_port  flow_duration  ...  idle_min   label
# 0             54865              3  ...         0  BENIGN
# 1             55054            109  ...         0  BENIGN
# 2             55055             52  ...         0  BENIGN
# 3             46236             34  ...         0  BENIGN
# 4             54863              3  ...         0  BENIGN
#
# [5 rows x 78 columns]

# %%
pcap.columns.sort_values()
# Out:
# Index(['ACK Flag Cnt', 'Active Max', 'Active Mean', 'Active Min', 'Active Std',
#        'Bwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Header Len', 'Bwd IAT Max',
#        'Bwd IAT Mean', 'Bwd IAT Min', 'Bwd IAT Std', 'Bwd IAT Tot',
#        'Bwd PSH Flags', 'Bwd Pkt Len Max', 'Bwd Pkt Len Mean',
#        'Bwd Pkt Len Min', 'Bwd Pkt Len Std', 'Bwd Pkts/b Avg', 'Bwd Pkts/s',
#        'Bwd Seg Size Avg', 'Bwd URG Flags', 'CWE Flag Count', 'Down/Up Ratio',
#        'Dst Port', 'ECE Flag Cnt', 'FIN Flag Cnt', 'Flow Byts/s',
#        'Flow Duration', 'Flow IAT Max', 'Flow IAT Mean', 'Flow IAT Min',
#        'Flow IAT Std', 'Flow Pkts/s', 'Fwd Act Data Pkts', 'Fwd Blk Rate Avg',
#        'Fwd Byts/b Avg', 'Fwd Header Len', 'Fwd IAT Max', 'Fwd IAT Mean',
#        'Fwd IAT Min', 'Fwd IAT Std', 'Fwd IAT Tot', 'Fwd PSH Flags',
#        'Fwd Pkt Len Max', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Min',
#        'Fwd Pkt Len Std', 'Fwd Pkts/b Avg', 'Fwd Pkts/s', 'Fwd Seg Size Avg',
# ...

# %%
clear_pcap_data = pcap.rename(columns={'ACK Flag Cnt':'ack_flag_count', 'Active Max':'active_max', 
                                   'Active Min':'active_min', 'Active Std':'active_std',
                                  'Pkt Size Avg':'avg_packet_size', 'Bwd Seg Size Avg':'avg_bwd_segment_size',
                                  'Fwd Seg Size Avg':'avg_fwd_segment_size', 'Bwd Byts/b Avg':'bwd_avg_bytes_bulk', 
                                  'Bwd Pkts/b Avg':'bwd_avg_packets_bulk', 'Bwd Header Len':'bwd_header_length', 
                                  'Bwd IAT Max':'bwd_iat_max', 'Bwd IAT Mean':'bwd_iat_mean',
                                  'Bwd IAT Min':'bwd_iat_min', 'Bwd IAT Std':'bwd_iat_std', 
                                  'Bwd PSH Flags':'bwd_psh_flags', 'Bwd Pkt Len Mean':'bwd_packet_length_mean',
                                  'Bwd Pkt Len Min':'bwd_packet_length_min', 'Bwd Pkt Len Std':'bwd_packet_length_std',
                                  'Bwd Pkts/s':'bwd_packets_s', 'Bwd URG Flags':'bwd_urg_flags', 
                                  'CWE Flag Count':'cwe_flag_count', 'Dst Port':'destination_port',
                                  'Down/Up Ratio':'down_up_ratio', 'ECE Flag Cnt':'ece_flag_count', 
                                  'Flow Duration':'flow_duration', 'Flow IAT Max':'flow_iat_max',
                                  'Flow IAT Mean':'flow_iat_mean', 'Flow IAT Min':'flow_iat_min', 
                                  'Flow IAT Std':'flow_iat_std', 'Flow Pkts/s':'flow_packets_s',
                                  'Fwd Blk Rate Avg':'fwd_avg_bulk_rate', 'Fwd Pkts/b Avg':'fwd_avg_packets_bulk', 
                                  'Fwd Header Len':'fwd_header_length', 'Fwd IAT Max':'fwd_iat_max',
                                  'Fwd IAT Mean':'fwd_iat_mean', 'Fwd IAT Min':'fwd_iat_min', 
                                  'Fwd IAT Std':'fwd_iat_std', 'Fwd Pkt Len Max':'fwd_packet_length_max', 
                                  'Fwd Pkt Len Mean':'fwd_packet_length_mean', 'Fwd Pkt Len Min':'fwd_packet_length_min', 
                                  'Fwd Pkt Len Std':'fwd_packet_length_std', 'Fwd URG Flags':'fwd_urg_flags',
                                  'Idle Max':'idle_max', 'Idle Min':'idle_min', 'Idle Std':'idle_std', 
                                  'Init Bwd Win Byts':'init_win_bytes_bwd', 'Label':'label', 
                                  'Pkt Len Max':'max_packet_length', 'Pkt Len Min':'min_packet_length', 
                                  'PSH Flag Cnt':'psh_flag_count', 'Pkt Len Mean':'packet_length_mean', 
                                  'Pkt Len Std':'packet_length_std', 'Pkt Len Var':'packet_length_variance',
                                  'RST Flag Cnt':'rst_flag_count', 'SYN Flag Cnt':'syn_flag_count', 
                                  'Subflow Bwd Byts':'subflow_bwd_bytes', 'Subflow Bwd Pkts':'subflow_bwd_packets', 
                                  'Subflow Fwd Byts':'subflow_fwd_bytes', 'Tot Bwd Pkts':'total_bwd_packets',
                                  'Tot Fwd Pkts':'total_fwd_packets', 'TotLen Bwd Pkts':'total_length_of_bwd_packets', 
                                  'URG Flag Cnt':'urg_flag_count', 'Fwd Act Data Pkts':'act_data_pkt_fwd', 
                                  'Fwd Seg Size Min':'min_seg_size_forward', 'Active Mean':'active_mean',
                                  'Bwd Blk Rate Avg':'bwd_avg_bulk_rate', 'Bwd IAT Tot':'bwd_iat_total', 
                                  'Bwd Packet Length Max':'bwd_packet_length_max', 'FIN Flag Cnt':'fin_flag_count', 
                                  'Flow Byts/s':'flow_bytes_s', 'Fwd Byts/b Avg':'fwd_avg_bytes_bulk', 
                                  'Fwd IAT Tot':'fwd_iat_total', 'Fwd PSH Flags':'fwd_psh_flags', 
                                  'Fwd Pkts/s':'fwd_packets_s', 'Idle Mean':'idle_mean', 
                                  'Init Fwd Win Byts':'init_win_bytes_fwd', 'Subflow Fwd Pkts':'subflow_fwd_packets', 
                                  'TotLen Fwd Pkts':'total_length_of_fwd_packets'})

# %%
clear_pcap_data.head()
# Out:
#    destination_port  flow_duration  ...      idle_min     label
# 0               443          23164  ...  0.000000e+00  No Label
# 1             54080        7109135  ...  7.022435e+06  No Label
# 2               443       59745764  ...  1.591874e+15  No Label
# 3               443          14011  ...  0.000000e+00  No Label
# 4               443       58312187  ...  1.591874e+15  No Label
#
# [5 rows x 78 columns]

# %%
clear_df_data.isnull().sum()
# Out:
# destination_port               0
# flow_duration                  0
# total_fwd_packets              0
# total_bwd_packets              0
# total_length_of_fwd_packets    0
#                               ..
# idle_mean                      0
# idle_std                       0
# idle_max                       0
# idle_min                       0
# label                          0
# Length: 78, dtype: int64

# %%
clear_pcap_data.isnull().sum()
# Out:
# destination_port               0
# flow_duration                  0
# total_fwd_packets              0
# total_bwd_packets              0
# total_length_of_fwd_packets    0
#                               ..
# idle_mean                      0
# idle_std                       0
# idle_max                       0
# idle_min                       0
# label                          0
# Length: 78, dtype: int64

# %%
clear_df = clear_df_data.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
clear_pcap = clear_pcap_data.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
clear_df.isnull().sum()
# Out:
# destination_port               0
# flow_duration                  0
# total_fwd_packets              0
# total_bwd_packets              0
# total_length_of_fwd_packets    0
#                               ..
# idle_mean                      0
# idle_std                       0
# idle_max                       0
# idle_min                       0
# label                          0
# Length: 78, dtype: int64

# %%
clear_df.flow_bytes_s.nunique()
# Out:
# 1593908

# %%
clear_df.flow_packets_s.nunique()
# Out:
# 1240164

# %%
clear_df = clear_df.drop(['flow_bytes_s', 'flow_packets_s'], axis = 1)

# %%
clear_pcap = clear_pcap.drop(['flow_bytes_s', 'flow_packets_s'], axis = 1)

# %%
clear_pcap = clear_pcap.drop(['label'], axis = 1)

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
clear_df.label = label_encoder.fit_transform(clear_df.label)

# %%
clear_df.head()
# Out:
#    destination_port  flow_duration  ...  idle_min  label
# 0             54865              3  ...         0      0
# 1             55054            109  ...         0      0
# 2             55055             52  ...         0      0
# 3             46236             34  ...         0      0
# 4             54863              3  ...         0      0
#
# [5 rows x 76 columns]

# %%
X = clear_df.drop(['label'], axis = 1)
y = clear_df.label

# %%
import matplotlib.pyplot as plt

# %%
df_attack_cats = df[' Label'].value_counts()
df_attack_cats.plot(kind='barh')

# %%
df_attack_cats
# Out:
# BENIGN                        2273097
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# FTP-Patator                      7938
# SSH-Patator                      5897
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1966
# Web Attack � Brute Force         1507
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name:  Label, dtype: int64

# %%
df_attack_cats_encoded = clear_df['label'].value_counts()
df_attack_cats_encoded
# Out:
# 0     2272688
# 4      230124
# 10     158930
# 2      128027
# 3       10293
# 7        7938
# 11       5897
# 6        5796
# 5        5499
# 1        1966
# 12       1507
# 14        652
# 9          36
# 13         21
# 8          11
# Name: label, dtype: int64

# %% [markdown]
# 0 - BENIGN
# 1 - Bot
# 2 - DDoS
# 3 - DoS GoldenEye
# 4 - DoS Hulk
# 5 - DoS Slowhttptest
# 6 - DoS slowloris
# 7 - FTP-Patator
# 8 - Heartbleed
# 9 - Infiltration
# 10 - PortScan
# 11 - SSH-Patator
# 12 - Web Attack � Brute Force
# 13 - Web Attack � Sql Injection
# 14 - Web Attack � XSS

# %%
correlation = clear_df.corr()

# %%
correlation
# Out:
#                              destination_port  ...     label
# destination_port                     1.000000  ... -0.078331
# flow_duration                       -0.151719  ...  0.072754
# total_fwd_packets                   -0.004237  ... -0.003322
# total_bwd_packets                   -0.003948  ... -0.003119
# total_length_of_fwd_packets          0.011148  ... -0.014859
# ...                                       ...  ...       ...
# idle_mean                           -0.112612  ...  0.187838
# idle_std                             0.010403  ...  0.023298
# idle_max                            -0.108211  ...  0.186416
# idle_min                            -0.114642  ...  0.187252
# label                               -0.078331  ...  1.000000
#
# [76 rows x 76 columns]

# %%
cor_target = abs(correlation.label)

# %%
cor_target
# Out:
# destination_port               0.078331
# flow_duration                  0.072754
# total_fwd_packets              0.003322
# total_bwd_packets              0.003119
# total_length_of_fwd_packets    0.014859
#                                  ...
# idle_mean                      0.187838
# idle_std                       0.023298
# idle_max                       0.186416
# idle_min                       0.187252
# label                          1.000000
# Name: label, Length: 76, dtype: float64

# %%
relevant_features = cor_target[cor_target>0.05]

# %%
relevant_features.sort_values(ascending=False)
# Out:
# label                     1.000000
# psh_flag_count            0.305725
# min_packet_length         0.254347
# bwd_packet_length_min     0.226898
# fwd_iat_std               0.206005
# idle_mean                 0.187838
# idle_min                  0.187252
# idle_max                  0.186416
# fwd_iat_max               0.182538
# bwd_packet_length_std     0.182338
# flow_iat_max              0.181326
# bwd_packet_length_max     0.172158
# bwd_packet_length_mean    0.158381
# avg_bwd_segment_size      0.158381
# packet_length_variance    0.156013
# flow_iat_std              0.153087
# packet_length_std         0.152022
# max_packet_length         0.149831
# fwd_packet_length_min     0.115060
# urg_flag_count            0.115042
# packet_length_mean        0.111534
# bwd_packets_s             0.108541
# avg_packet_size           0.107363
# init_win_bytes_fwd        0.101387
# fin_flag_count            0.096035
# fwd_packet_length_mean    0.086974
# avg_fwd_segment_size      0.086974
# ...

# %%
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()
model.fit(X, y)
importance = model.feature_importances_

# %%
feature_importances_df = pd.DataFrame({'features': list(X), 'feature_importances': importance})

# %%
most_important = feature_importances_df.sort_values(by='feature_importances', ascending=False).head(30)

# %%
most_important
# Out:
#                   features  feature_importances
# 44          psh_flag_count             0.063447
# 0         destination_port             0.048562
# 39       packet_length_std             0.045037
# 66    min_seg_size_forward             0.041537
# 13   bwd_packet_length_std             0.032295
# 63      init_win_bytes_fwd             0.031891
# 50         avg_packet_size             0.030341
# 10   bwd_packet_length_max             0.028240
# 38      packet_length_mean             0.028230
# 12  bwd_packet_length_mean             0.028127
# 52    avg_bwd_segment_size             0.027849
# 21             fwd_iat_max             0.026846
# 71               idle_mean             0.026747
# 11   bwd_packet_length_min             0.026719
# 45          ack_flag_count             0.026670
# 20             fwd_iat_std             0.025324
# 16            flow_iat_max             0.025175
# 74                idle_min             0.022799
# 34           fwd_packets_s             0.021201
# ...

# %%
X_1=X[most_important.features].copy()
X_1.head()
# Out:
#    psh_flag_count  destination_port  ...  subflow_fwd_packets  avg_fwd_segment_size
# 0               0             54865  ...                    2                   6.0
# 1               0             55054  ...                    1                   6.0
# 2               0             55055  ...                    1                   6.0
# 3               0             46236  ...                    1                   6.0
# 4               0             54863  ...                    2                   6.0
#
# [5 rows x 30 columns]

# %%
most_important.features.tolist()
# Out:
# ['psh_flag_count',
#  'destination_port',
#  'min_seg_size_forward',
#  'avg_bwd_segment_size',
#  'bwd_packet_length_std',
#  'packet_length_std',
#  'avg_packet_size',
#  'fwd_iat_max',
#  'init_win_bytes_fwd',
#  'flow_iat_max',
#  'bwd_packet_length_max',
#  'bwd_packet_length_min',
#  'ack_flag_count',
#  'idle_mean',
#  'bwd_packet_length_mean',
#  'fwd_iat_std',
#  'idle_max',
#  'fwd_iat_total',
#  'max_packet_length',
#  'packet_length_mean',
#  'fwd_packets_s',
#  'idle_min',
#  'min_packet_length',
#  'flow_duration',
#  'act_data_pkt_fwd',
#  'packet_length_variance',
#  'fwd_packet_length_min',
#  'fin_flag_count',
#  'subflow_fwd_packets',
#  'avg_fwd_segment_size']

# %%
feat = ['psh_flag_count','destination_port','min_seg_size_forward','avg_bwd_segment_size',
 'bwd_packet_length_std','packet_length_std', 'avg_packet_size', 'fwd_iat_max',
 'init_win_bytes_fwd','flow_iat_max','bwd_packet_length_max','bwd_packet_length_min',
 'ack_flag_count','idle_mean','bwd_packet_length_mean','fwd_iat_std','idle_max',
 'fwd_iat_total','max_packet_length','packet_length_mean','fwd_packets_s','idle_min',
 'min_packet_length','flow_duration','act_data_pkt_fwd','packet_length_variance',
 'fwd_packet_length_min','fin_flag_count','subflow_fwd_packets','avg_fwd_segment_size', 'label']

# %%
data=clear_df[feat].copy()
data.head()
# Out:
# 'data=clear_df[feat].copy()\ndata.head()'

# %%
data.to_csv(r'drive/My Drive/datasets/data.csv', index = False)
# Out:
# "data.to_csv(r'drive/My Drive/datasets/data.csv', index = False)"
